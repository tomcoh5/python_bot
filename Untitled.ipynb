# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open("Computer-Vision-with-Python/DATA/00-puppy.jpg")

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()
plt.imshow(pic_red,cmpa=)

# %%
pic_red.shape
# Out:
# (1300, 1950, 3)

# %%
# R G B 0-255
plt.imshow(pic_red[:,:,0]) # Red Channel

# %%
plt.imshow(pic_red[:,:,1]) # Green Channel

# %%
pic_red[:,:,2] = 0

# %%
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)
